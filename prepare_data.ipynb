# %%
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
source_file_name = 'MICC-F220/original_groundtruthDB_220.txt'

with open(source_file_name) as source_file:
    img_names = source_file.readlines()

print(len(img_names))
# Out:
# 220

# %%
img_cl_names = []
for line in img_names:
    line = line[:-1]
    line = ' '.join(line.split())
    img_cl_names.append([line.split(' ')[0], int(line.split(' ')[1])])
print(img_cl_names)
# Out:
# [['CRW_4853tamp1.jpg', 1], ['CRW_4853tamp131.jpg', 1], ['CRW_4853tamp132.jpg', 1], ['CRW_4853tamp133.jpg', 1], ['CRW_4853tamp134.jpg', 1], ['CRW_4853tamp176.jpg', 1], ['CRW_4853tamp237.jpg', 1], ['CRW_4853tamp25.jpg', 1], ['CRW_4853tamp27.jpg', 1], ['CRW_4853tamp37.jpg', 1], ['CRW_4901_JFRtamp1.jpg', 1], ['CRW_4901_JFRtamp131.jpg', 1], ['CRW_4901_JFRtamp132.jpg', 1], ['CRW_4901_JFRtamp133.jpg', 1], ['CRW_4901_JFRtamp134.jpg', 1], ['CRW_4901_JFRtamp176.jpg', 1], ['CRW_4901_JFRtamp237.jpg', 1], ['CRW_4901_JFRtamp25.jpg', 1], ['CRW_4901_JFRtamp27.jpg', 1], ['CRW_4901_JFRtamp37.jpg', 1], ['DSC_0535tamp1.jpg', 1], ['DSC_0535tamp131.jpg', 1], ['DSC_0535tamp132.jpg', 1], ['DSC_0535tamp133.jpg', 1], ['DSC_0535tamp134.jpg', 1], ['DSC_0535tamp176.jpg', 1], ['DSC_0535tamp237.jpg', 1], ['DSC_0535tamp25.jpg', 1], ['DSC_0535tamp27.jpg', 1], ['DSC_0535tamp37.jpg', 1], ['DSC_0812tamp1.jpg', 1], ['DSC_0812tamp131.jpg', 1], ['DSC_0812tamp132.jpg', 1], ['DSC_0812tamp133.jpg', 1], ['DSC_0812tamp134.jpg', 1], ['DSC_0812tamp176.jpg', 1], ['DSC_0812tamp237.jpg', 1], ['DSC_0812tamp25.jpg', 1], ['DSC_0812tamp27.jpg', 1], ['DSC_0812tamp37.jpg', 1], ['DSC_1535tamp1.jpg', 1], ['DSC_1535tamp131.jpg', 1], ['DSC_1535tamp132.jpg', 1], ['DSC_1535tamp133.jpg', 1], ['DSC_1535tamp134.jpg', 1], ['DSC_1535tamp176.jpg', 1], ['DSC_1535tamp237.jpg', 1], ['DSC_1535tamp25.jpg', 1], ['DSC_1535tamp27.jpg', 1], ['DSC_1535tamp37.jpg', 1], ['DSC_1540tamp1.jpg', 1], ['DSC_1540tamp131.jpg', 1], ['DSC_1540tamp132.jpg', 1], ['DSC_1540tamp133.jpg', 1], ['DSC_1540tamp134.jpg', 1], ['DSC_1540tamp176
g', 0], ['CRW_4834_scale.jpg', 0], ['CRW_4835_scale.jpg', 0], ['CRW_4836_scale.jpg', 0], ['CRW_4838_scale.jpg', 0], ['CRW_4839_scale.jpg', 0], ['CRW_4840_scale.jpg', 0], ['CRW_4841_scale.jpg', 0], ['CRW_4842_scale.jpg', 0], ['CRW_4848_scale.jpg', 0], ['CRW_4852_scale.jpg', 0], ['CRW_4853_scale.jpg', 0], ['CRW_4901_JFR_scale.jpg', 0], ['DSC_0535_scale.jpg', 0], ['DSC_0812_scale.jpg', 0], ['DSC_1535_scale.jpg', 0], ['DSC_1538_scale.jpg', 0], ['DSC_1539_scale.jpg', 0], ['DSC_1540_scale.jpg', 0], ['DSC_1542_scale.jpg', 0], ['DSC_1546_scale.jpg', 0], ['DSC_1549_scale.jpg', 0], ['DSC_1550_ ...

# %%
img = cv2.imread('MICC-F220/original_img_220/CRW_4809_scale.jpg')
print(img.shape)
plt.imshow(img)
# Out:
# (492, 737, 3)

# %%
img_cropped = img[0:0+256, 0:0+256]
print(img_cropped.shape)
plt.imshow(img_cropped)
# Out:
# (256, 256, 3)

# %%
img_cl_names[0][0]
# Out:
# 'CRW_4853tamp1.jpg'

# %%
with open('MICC-F220/ext_classes.txt', 'w') as dest_file:
    for img_data in img_cl_names:
        img = cv2.imread('MICC-F220/original_img_220/' + img_data[0])
        height = img.shape[0]
        width = img.shape[1]
        img_0 = img[0:256, 0:256]
        img_1 = img[0:256, width-256:width]
        img_2 = img[height-256:height, 0:256]
        img_3 = img[height-256:height, width-256:width]
        img_4 = img[int(height/2)-128:int(height/2)+128, int(width/2)-128:int(width/2)+128]

        cv2.imwrite('MICC-F220/extended_imgs_1100/' + img_data[0].split('.')[0] + '_0.png', img_0)
        cv2.imwrite('MICC-F220/extended_imgs_1100/' + img_data[0].split('.')[0] + '_1.png', img_1)
        cv2.imwrite('MICC-F220/extended_imgs_1100/' + img_data[0].split('.')[0] + '_2.png', img_2)
        cv2.imwrite('MICC-F220/extended_imgs_1100/' + img_data[0].split('.')[0] + '_3.png', img_3)
        cv2.imwrite('MICC-F220/extended_imgs_1100/' + img_data[0].split('.')[0] + '_4.png', img_4)

        dest_file.write(img_data[0].split('.')[0] + '_0.png\t' + str(img_data[1]) + '\n')
        dest_file.write(img_data[0].split('.')[0] + '_1.png\t' + str(img_data[1]) + '\n')
        dest_file.write(img_data[0].split('.')[0] + '_2.png\t' + str(img_data[1]) + '\n')
        dest_file.write(img_data[0].split('.')[0] + '_3.png\t' + str(img_data[1]) + '\n')
        dest_file.write(img_data[0].split('.')[0] + '_4.png\t' + str(img_data[1]) + '\n')

dest_file.close()
